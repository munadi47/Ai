# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
data = pd.read_csv('train.csv')

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# Handling missing value (mode = modus mengambil nilai terbanyak)
data['Gender'] = data['Gender'].fillna(data['Gender'].mode()[0])

# Handling missing value (mean = modus mengambil nilai rata rata)
data['LoanAmount'] = data['LoanAmount'].fillna(data['LoanAmount'].mean())

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#object pake mode, klo numeric/float pake mean
data['Married'] = data['Married'].fillna(data['Married'].mode()[0])
data['Dependents'] = data['Dependents'].fillna(data['Dependents'].mode()[0])
data['Self_Employed'] = data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])
data['Loan_Amount_Term'] = data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mean())
data['Credit_History'] = data['Credit_History'].fillna(data['Credit_History'].mean())

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print(pd.value_counts(data.Gender))
print(pd.value_counts(data.Education))
print(pd.value_counts(data.Married))
print(pd.value_counts(data.Dependents))
print(pd.value_counts(data.Self_Employed))
print(pd.value_counts(data.Property_Area))

#setelah ini akan dilakukan transformasi yang mengubah object
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# Dependents
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
map_gender = dict(zip(set(data['Gender']), [1,2]))
data['Gender'] = data['Gender'].apply(lambda x:map_gender[x])
print(map_gender)
# Out:
# {'Female': 1, 'Male': 2}

# %%
map_edu = dict(zip(set(data['Education']), [1,2]))
data['Education'] = data['Education'].apply(lambda x:map_edu[x])
print(map_edu)
# Out:
# {'Graduate': 1, 'Not Graduate': 2}

# %%
map_edu = dict(zip(set(data['Married']), [1,2]))
data['Married'] = data['Married'].apply(lambda x:map_edu[x])
print(map_edu)
# Out:
# {'Yes': 1, 'No': 2}

# %%
map_edu = dict(zip(set(data['Dependents']), [1,2,3,4]))
data['Dependents'] = data['Dependents'].apply(lambda x:map_edu[x])
print(map_edu)
# Out:
# {'0': 1, '1': 2, '2': 3, '3+': 4}

# %%
map_edu = dict(zip(set(data['Self_Employed']), [1,2]))
data['Self_Employed'] = data['Self_Employed'].apply(lambda x:map_edu[x])
print(map_edu)
# Out:
# {'Yes': 1, 'No': 2}

# %%
map_edu = dict(zip(set(data['Property_Area']), [1,2,3]))
data['Property_Area'] = data['Property_Area'].apply(lambda x:map_edu[x])
print(map_edu)
# Out:
# {'Rural': 1, 'Semiurban': 2, 'Urban': 3}

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       2        2           1          1              2
# 1  LP001003       2        1           2          1              2
# 2  LP001005       2        1           1          1              1
# 3  LP001006       2        1           1          2              2
# 4  LP001008       2        2           1          1              2
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              3           Y
# 1             1.0              1           N
# ...

# %%
data.drop('Loan_ID', axis= 1, inplace = True)
data.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       2        2           1          1              2             5849
# 1       2        1           2          1              2             4583
# 2       2        1           1          1              1             3000
# 3       2        1           1          2              2             2583
# 4       2        2           1          1              2             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area Loan_Status
# 0              3           Y
# 1              1           N
# ...
